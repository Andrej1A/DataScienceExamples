# %% [markdown]
# # World Population 1960 - 2018

# %%
import numpy as np
import pandas as pd
from pathlib import Path

# Import
df = pd.read_csv(Path('world-population-19602018/population_total_long.csv'))

# Export
# df.to_csv('export/calculated.csv')

# Head
df.head()
# Out:
#   Country Name  Year    Count
# 0        Aruba  1960    54211
# 1  Afghanistan  1960  8996973
# 2       Angola  1960  5454933
# 3      Albania  1960  1608800
# 4      Andorra  1960    13411

# %%
df.shape
# Out:
# (12595, 3)

# %%
df.describe()
# Out:
#                Year         Count
# count  12595.000000  1.259500e+04
# mean    1988.583406  2.377748e+07
# std       16.744033  1.002442e+08
# min     1960.000000  3.893000e+03
# 25%     1974.000000  4.758955e+05
# 50%     1989.000000  4.060260e+06
# 75%     2003.000000  1.276995e+07
# max     2017.000000  1.386395e+09

# %% [markdown]
# ## Group By

# %%
#df.keys
germanySelect = df['Country Name'] == 'Germany'

germany = df.loc[germanySelect]

germany
# Out:
#       Country Name  Year     Count
# 51         Germany  1960  72814900
# 267        Germany  1961  73377632
# 483        Germany  1962  74025784
# 699        Germany  1963  74714353
# 915        Germany  1964  75318337
# 1131       Germany  1965  75963695
# 1347       Germany  1966  76600311
# 1563       Germany  1967  76951336
# 1779       Germany  1968  77294314
# 1995       Germany  1969  77909682
# 2211       Germany  1970  78169289
# 2427       Germany  1971  78312842
# 2643       Germany  1972  78688452
# 2859       Germany  1973  78936666
# 3075       Germany  1974  78967433
# 3291       Germany  1975  78673554
# 3507       Germany  1976  78336950
# 3723       Germany  1977  78159814
# 3939       Germany  1978  78091820
# 4155       Germany  1979  78126350
# 4371       Germany  1980  78288576
# 4587       Germany  1981  78407907
# 4803       Germany  1982  78333366
# 5019       Germany  1983  78128282
# 5235       Germany  1984  77858685
# 5451       Germany  1985  77684873
# ...
